# %%
# import necasery laibares
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read data set
df=pd.read_csv("/content/hose_train.csv")
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
df.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# ...

# %%
df.tail()
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# 29446              1       1               Shamshabad Road,Agra  27.140626
# 29447              1       1  E3-108, Lake View Recidency,,Vapi  39.945409
# 29448              1       1                  Ajmer Road,Jaipur  26.928785
# 29449              1       1             Sholinganallur,Chennai  12.900150
# 29450              1       1                   Jagatpura,Jaipur  26.832353
#
#         LATITUDE  TARGET(PRICE_IN_LACS)
# ...

# %%
# columns count and names
print ( "columns_count :", df.shape[1])
print ( "row_count :", df.shape[0])
print ("names: ","\n",df.columns)
# Out:
# columns_count : 12
# row_count : 29451
# names:
#  Index(['POSTED_BY', 'UNDER_CONSTRUCTION', 'RERA', 'BHK_NO.', 'BHK_OR_RK',
#        'SQUARE_FT', 'READY_TO_MOVE', 'RESALE', 'ADDRESS', 'LONGITUDE',
#        'LATITUDE', 'TARGET(PRICE_IN_LACS)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# POSTED_BY                 object
# UNDER_CONSTRUCTION         int64
# RERA                       int64
# BHK_NO.                    int64
# BHK_OR_RK                 object
# SQUARE_FT                float64
# READY_TO_MOVE              int64
# RESALE                     int64
# ADDRESS                   object
# LONGITUDE                float64
# LATITUDE                 float64
# TARGET(PRICE_IN_LACS)    float64
# dtype: object

# %%
# information about the total number of rows, the number of non-null values in each column, and the data type of each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   ADDRESS                29451 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %%
# generate a statistical summary of the DataFrame
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
# show the count of missing values in each column of the DataFrame
df.isna().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
# drop unnececcery columns
df.drop(['POSTED_BY','ADDRESS'],axis=1,inplace=True)
df
# Out:
#        UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0                       0     0        2       BHK  1300.236407
# 1                       0     0        2       BHK  1275.000000
# 2                       0     0        2       BHK   933.159722
# 3                       0     1        2       BHK   929.921143
# 4                       1     0        2       BHK   999.009247
# ...                   ...   ...      ...       ...          ...
# 29446                   0     0        3       BHK  2500.000000
# 29447                   0     0        2       BHK   769.230769
# 29448                   0     0        2       BHK  1022.641509
# 29449                   0     0        2       BHK   927.079009
# 29450                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)
# 0                  1       1  12.969910  77.597960                   55.0
# ...

# %%
df1=pd.read_csv("/content/hose_train.csv")
df1
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
df2=df1['UNDER_CONSTRUCTION'].replace({0:"no",1:"yes"},inplace=True)

# %%
df2=df1['RERA'].replace({0:"no",1:"yes"},inplace=True)

# %%
df2=df1['RESALE'].replace({0:"no",1:"yes"},inplace=True)

# %%
df2=df1['READY_TO_MOVE'].replace({0:"no",1:"yes"},inplace=True)

# %%
df1.head()
# Out:
#   POSTED_BY UNDER_CONSTRUCTION RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                 no   no        2       BHK  1300.236407
# 1    Dealer                 no   no        2       BHK  1275.000000
# 2     Owner                 no   no        2       BHK   933.159722
# 3     Owner                 no  yes        2       BHK   929.921143
# 4    Dealer                yes   no        2       BHK   999.009247
#
#   READY_TO_MOVE RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0           yes    yes        Ksfc Layout,Bangalore  12.969910  77.597960
# 1           yes    yes    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2           yes    yes             Jigani,Bangalore  12.778033  77.632191
# 3           yes    yes  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4            no    yes             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# 2                   43.0
# ...

# %%
constaction=df1['UNDER_CONSTRUCTION'].value_counts()
constaction.plot(kind='pie',fontsize=12,autopct='%1.1f%%')
plt.title('UNDER_CONSTRUCTION graph',color='blue',fontsize=14)
# Out:
# Text(0.5, 1.0, 'UNDER_CONSTRUCTION graph')

# %%
print(df1['RERA'].value_counts())
print(sns.countplot(x=df['RERA'],data=df))
# Out:
# no     20088
# yes     9363
# Name: RERA, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df1['BHK_NO.'].value_counts())
print(sns.countplot(x=df['BHK_NO.'],data=df))
# Out:
# 2     13324
# 3     10546
# 1      3574
# 4      1723
# 5       190
# 6        52
# 7        11
# 8        10
# 20        4
# 10        4
# 15        4
# 12        3
# 9         3
# 13        1
# 17        1
# 11        1
# Name: BHK_NO., dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
bhk=df1['BHK_OR_RK'].value_counts()
bhk.plot(kind='pie',fontsize=12,autopct='%1.1f%%')
plt.title('UNDER_CONSTRUCTION graph',color='blue',fontsize=14)
# Out:
# Text(0.5, 1.0, 'UNDER_CONSTRUCTION graph')

# %%
ready=df1['READY_TO_MOVE'].value_counts()
ready.plot(kind='pie',fontsize=12,autopct='%1.1f%%')
plt.title('UNDER_CONSTRUCTION graph',color='blue',fontsize=14)
# Out:
# Text(0.5, 1.0, 'UNDER_CONSTRUCTION graph')

# %%
resale=df1['RESALE'].value_counts()
resale.plot(kind='pie',fontsize=12,autopct='%1.1f%%')
plt.title('UNDER_CONSTRUCTION graph',color='blue',fontsize=14)
# Out:
# Text(0.5, 1.0, 'UNDER_CONSTRUCTION graph')

# %%
sns.regplot(x=df1["SQUARE_FT"],y=df["TARGET(PRICE_IN_LACS)"],color="green")
# Out:
# <Axes: xlabel='SQUARE_FT', ylabel='TARGET(PRICE_IN_LACS)'>

# %%
sns.regplot(x=df1["BHK_NO."],y=df["TARGET(PRICE_IN_LACS)"],color="red")
# Out:
# <Axes: xlabel='BHK_NO.', ylabel='TARGET(PRICE_IN_LACS)'>

# %%
sns.regplot(x=df1["LONGITUDE"],y=df["TARGET(PRICE_IN_LACS)"],color="red")
# Out:
# <Axes: xlabel='LONGITUDE', ylabel='TARGET(PRICE_IN_LACS)'>

# %%
sns.regplot(x=df1["LATITUDE"],y=df["TARGET(PRICE_IN_LACS)"],color="red")
# Out:
# <Axes: xlabel='LATITUDE', ylabel='TARGET(PRICE_IN_LACS)'>

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-27-13d48a71d0da>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
# preprocessing data(cleaning and organising)
from sklearn.preprocessing import  OrdinalEncoder
le=OrdinalEncoder()

# %%
df[['BHK_OR_RK']]=le.fit_transform(df[['BHK_OR_RK']])

# %%
df.head()
# Out:
#    UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK    SQUARE_FT  READY_TO_MOVE  \
# 0                   0     0        2        0.0  1300.236407              1
# 1                   0     0        2        0.0  1275.000000              1
# 2                   0     0        2        0.0   933.159722              1
# 3                   0     1        2        0.0   929.921143              1
# 4                   1     0        2        0.0   999.009247              0
#
#    RESALE  LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)
# 0       1  12.969910  77.597960                   55.0
# 1       1  12.274538  76.644605                   51.0
# 2       1  12.778033  77.632191                   43.0
# 3       1  28.642300  77.344500                   62.5
# 4       1  22.592200  88.484911                   60.5

# %%
# df['UNDER_CONSTRUCTION'] = df['UNDER_CONSTRUCTION'].astype(float)

# %%
df['BHK_NO.'] = df['BHK_NO.'].astype(float)

# %%
df['READY_TO_MOVE'] = df['READY_TO_MOVE'].astype(float)

# %%
df['RESALE'] = df['RESALE'].astype(float)

# %%
df['RERA'] = df['RERA'].astype(float)

# %%
df.dtypes
# Out:
# UNDER_CONSTRUCTION         int64
# RERA                     float64
# BHK_NO.                  float64
# BHK_OR_RK                float64
# SQUARE_FT                float64
# READY_TO_MOVE            float64
# RESALE                   float64
# LONGITUDE                float64
# LATITUDE                 float64
# TARGET(PRICE_IN_LACS)    float64
# dtype: object

# %%
df.head()
# Out:
#    UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK    SQUARE_FT  READY_TO_MOVE  \
# 0                   0   0.0      2.0        0.0  1300.236407            1.0
# 1                   0   0.0      2.0        0.0  1275.000000            1.0
# 2                   0   0.0      2.0        0.0   933.159722            1.0
# 3                   0   1.0      2.0        0.0   929.921143            1.0
# 4                   1   0.0      2.0        0.0   999.009247            0.0
#
#    RESALE  LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)
# 0     1.0  12.969910  77.597960                   55.0
# 1     1.0  12.274538  76.644605                   51.0
# 2     1.0  12.778033  77.632191                   43.0
# 3     1.0  28.642300  77.344500                   62.5
# 4     1.0  22.592200  88.484911                   60.5

# %%
# This code extracts the feature variables and target variable
# input data/feature varible
x=df.iloc[:,:-1]
x
# Out:
#        UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK    SQUARE_FT  \
# 0                       0   0.0      2.0        0.0  1300.236407
# 1                       0   0.0      2.0        0.0  1275.000000
# 2                       0   0.0      2.0        0.0   933.159722
# 3                       0   1.0      2.0        0.0   929.921143
# 4                       1   0.0      2.0        0.0   999.009247
# ...                   ...   ...      ...        ...          ...
# 29446                   0   0.0      3.0        0.0  2500.000000
# 29447                   0   0.0      2.0        0.0   769.230769
# 29448                   0   0.0      2.0        0.0  1022.641509
# 29449                   0   0.0      2.0        0.0   927.079009
# 29450                   0   1.0      2.0        0.0   896.774194
#
#        READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE
# 0                1.0     1.0  12.969910  77.597960
# 1                1.0     1.0  12.274538  76.644605
# ...

# %%
# output data/target variable
y=df['TARGET(PRICE_IN_LACS)']
y
# Out:
# 0        55.0
# 1        51.0
# 2        43.0
# 3        62.5
# 4        60.5
#          ...
# 29446    45.0
# 29447    16.0
# 29448    27.1
# 29449    67.0
# 29450    27.8
# Name: TARGET(PRICE_IN_LACS), Length: 29451, dtype: float64

# %%
# split the feature variables (x) and target variable (y) into training and testing sets.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#        UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK    SQUARE_FT  \
# 27195                   0   0.0      2.0        0.0   800.000000
# 17167                   0   0.0      2.0        0.0    80.000000
# 17811                   0   0.0      2.0        0.0   980.157782
# 9185                    0   0.0      3.0        0.0  1549.333333
# 15340                   0   0.0      3.0        0.0  1317.218903
# ...                   ...   ...      ...        ...          ...
# 10955                   0   0.0      3.0        0.0  2857.142857
# 17289                   0   0.0      3.0        0.0  1350.016464
# 5192                    0   0.0      3.0        0.0  2550.019616
# 12172                   0   0.0      3.0        0.0  1278.159450
# 235                     0   0.0      4.0        0.0  2350.965575
#
#        READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE
# 27195            1.0     1.0  26.807408  75.838659
# 17167            1.0     1.0  27.221766  78.026673
# ...

# %%
x_test
# Out:
#        UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK      SQUARE_FT  \
# 11553                   0   1.0      3.0        0.0    1781.472684
# 16097                   0   0.0      3.0        0.0    1241.105411
# 23217                   0   0.0      2.0        0.0    1350.000000
# 16466                   1   1.0      3.0        0.0  126486.486500
# 12081                   0   0.0      3.0        0.0    1471.361009
# ...                   ...   ...      ...        ...            ...
# 8835                    1   1.0      2.0        0.0     665.043087
# 8286                    0   0.0      2.0        0.0     693.985459
# 6271                    1   0.0      4.0        0.0    1295.143213
# 14598                   0   1.0      3.0        0.0    1600.000000
# 1578                    0   0.0      3.0        0.0    1345.191773
#
#        READY_TO_MOVE  RESALE  LONGITUDE   LATITUDE
# 11553            1.0     1.0  28.651918  77.348794
# 16097            1.0     1.0  12.969910  77.597960
# ...

# %%
y_train
# Out:
# 27195     20.0
# 17167     22.0
# 17811     41.0
# 9185      58.1
# 15340     48.5
#          ...
# 10955    350.0
# 17289     41.0
# 5192      65.0
# 12172     80.0
# 235       56.0
# Name: TARGET(PRICE_IN_LACS), Length: 20615, dtype: float64

# %%
y_test
# Out:
# 11553     120.0
# 16097      75.0
# 23217      27.0
# 16466    7020.0
# 12081     140.0
#           ...
# 8835       71.0
# 8286       21.0
# 6271       52.0
# 14598      38.0
# 1578       48.4
# Name: TARGET(PRICE_IN_LACS), Length: 8836, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([149.51263771, 182.78455572, 111.55285476, ..., 194.16089752,
#        180.61528626, 184.82668427])

# %%
df5=pd.DataFrame({"Actual_value":y_test,"pedicted_value":y_pred,"diffarance":y_test-y_pred})
df5
# print(len(y_test), len(y_pred), len(y_test - y_pred))
# Out:
#        Actual_value  pedicted_value   diffarance
# 11553         120.0      149.512638   -29.512638
# 16097          75.0      182.784556  -107.784556
# 23217          27.0      111.552855   -84.552855
# 16466        7020.0      716.051117  6303.948883
# 12081         140.0      182.813913   -42.813913
# ...             ...             ...          ...
# 8835           71.0       83.863026   -12.863026
# 8286           21.0       27.277006    -6.277006
# 6271           52.0      194.160898  -142.160898
# 14598          38.0      180.615286  -142.615286
# 1578           48.4      184.826684  -136.426684
#
# [8836 rows x 3 columns]

# %%
print("constant values is :",model.intercept_)
print("coefficent :")
list(zip(x,model.coef_))
# Out:
# constant values is : 596.5447981587218
# coefficent :
# [('UNDER_CONSTRUCTION', -11.735043763544983),
#  ('RERA', 27.573776653350784),
#  ('BHK_NO.', 86.9640607860176),
#  ('BHK_OR_RK', -46.46501868590167),
#  ('SQUARE_FT', 0.0001274978059555565),
#  ('READY_TO_MOVE', 11.735043763544649),
#  ('RESALE', -517.5127545771636),
#  ('LONGITUDE', -3.9085922410202585),
#  ('LATITUDE', -1.5250254337568077)]

# %%
# 1. MAE   (mean absolute error)

from sklearn.metrics import mean_absolute_error
print("MAE is :",mean_absolute_error(y_test,y_pred))
# Out:
# MAE is : 138.1771658650951

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("percentage_error is :",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# percentage_error is : 1.8191673609250387

# %%
from sklearn.metrics import mean_squared_error
print("MSE is :",mean_squared_error(y_test,y_pred))
ae=mean_squared_error(y_test,y_pred)
# Out:
# MSE is : 357768.5229923336

# %%
print("Root mean squared error :",np.sqrt(ae))
# Out:
# Root mean squared error : 598.1375452120805

# %%
from sklearn.metrics import r2_score
print("r2_score :",r2_score(y_test,y_pred))
# Out:
# r2_score : 0.17034269290881365

# %%
y_pred=model.predict([[0.0,1.0,3.0,0.0,1781.472684,1.0,1.0,28.651918,77.348794]])
y_pred
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([149.51263771])
